# %% [markdown]
# <a href="https://colab.research.google.com/github/BacLuc/try-jupyter/blob/submit-colab/Practical1_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Practical 1 : Implementation of Linear Regression (Ridge, Lasso)
#
# This practical has two parts. The first part is to implement and train a linear regression model using the least squares method. We will implement the model and train it on the winequality dataset using the NumPy library. Learning curves will be plotted to determine if the model is overfitting or underfitting.
#
# In the second part, we will apply the basis expansion to the dataset and train linear regression models with regularization, i.e., Ridge and Lasso. These tasks do not need to be implemented from scratch -- We will use the functions from the scikit-learn library. During training, we use the validation data to determine the optimal hyperparameters.
# An optional task is to implement the hyperparameter selection using the k-fold cross-validation method. Five bonus points are awarded for this task.

# %% [markdown]
# We will use the following packages:

# %%
import numpy as np
import matplotlib.pyplot as plt
import _pickle as cp

# %% [markdown]
# ## Dataset
# We will use the winequality dataset for this practical. The dataset is available here:
# https://archive.ics.uci.edu/ml/datasets/Wine+Quality.
# In order to make it easier to import the dataset, the dataset has been converted to the numpy array format and shuffled, so that we can start the practical directly. The converted dataset is available on the OLAT page.
#
# #### Attribute Information
# Input variables (based on physicochemical tests):
# 1. fixed acidity
# 2. volatile acidity
# 3. citric acid
# 4. residual sugar
# 5. chlorides
# 6. free sulfur dioxide
# 7. total sulfur dioxide
# 8. density
# 9. pH
# 10. sulphates
# 11. alcohol
#
# Output variable (based on sensory data):
#
# 12. quality (score between 0 and 10)

# %% [markdown]
# There are two files in the dataset, one for white wine data and one for red wine data. We focus on the white wine data, which is the larger dataset. The following code loads the data:

# %%
# load the white wine dataset
# X is the feature matrix that stores the feature values of the data records
# y is the label vector that stores the labels of the data records
X, y = cp.load(open('winequality-white.pickle', 'rb'))

# check the size of the data
print("X is a matrix with the dimension {}. That is, {} data records and {} features.".format(X.shape, X.shape[0], X.shape[1]))
print("y is a vector with {} values. They are the labels of the data records in X.".format(y.shape[0]))
# Out:
# X is a matrix with the dimension (4898, 11). That is, 4898 data records and 11 features.
# y is a vector with 4898 values. They are the labels of the data records in X.

# %% [markdown]
# ## Understanding What We’re Predicting
#
# First, let's look at the labels.
# We make the bar chart below to show the distribution of labels in the dataset.
# The y-values are integers from 3 to 9.

# %%
# the function takes the y-values in the training data as the input and makes the bar chart. 
def plot_bar_chart_score(y):
    fix, ax = plt.subplots()
    unique, counts = np.unique(y, return_counts=True)
    plt.bar(unique, counts)
    plt.xlabel('Score')
    plt.ylabel('Number of wines')
    plt.title('Distribution of scores of wines')
    plt.show()

plot_bar_chart_score(y)

# %% [markdown]
# Our goal is to train a model that can take wine records in X and predict the quality of the wines.
# We split the data into training data and test data.
# In practice, we should sample randomly 80% of the data as training data and the rest as the test data.
# Though, in this practical, let's all use the same split: the **first** 80% of the data for training and the remaining 20% for testing. This makes sure we can compare your results to ours.

# %% [markdown]
# ### **Task 1**
# The first task is to write a function that can split the dataset into training and testing data according to the parameter `split_coeff`. When `split_coeff` is set to 0.8, it means the function sets the first 80% of the data as the training data and the remaining 20% as the testing data.

# %%
# The function splits the dataset into training data and testing data.
# The parameter split_coeff is a percentage value such that
# the first split_coeff of the dataset become the training data
# and the remaining data become the test data
def split_data(X, y, split_coeff=0.8):
    # The code below is just for compilation. 
    # You need to delete it and write your own code.
    ###################################################
    ##### YOUR CODE STARTS HERE #######################
    ###################################################

    size = len(y)
    size_train = int(split_coeff*size)
    size_test= size-size_train
    X_train = X[0: size_train,]
    y_train = y[0: size_train,]
    X_test = X[size_train:,]
    y_test = y[size_train:,]
    ###################################################
    ##### YOUR CODE ENDS HERE #########################
    ###################################################
    
    return X_train, y_train, X_test, y_test

# %% [markdown]
# Your function should return the expected output as shown in the code block below.

# %%
X_train, y_train, X_test, y_test = split_data(X, y, 0.8) # split the data with split_coeff=0.8

# check the size of the splitted dataset
print("Shape of X_train:", X_train.shape) # expected output (3918, 11)
print("Shape of y_train:", y_train.shape) # expected output (3918,)
print("Shape of X_test:", X_test.shape) # expected output (980, 11)
print("Shape of y_test:", y_test.shape) # expected output (980,)
# Out:
# Shape of X_train: (3918, 11)
# Shape of y_train: (3918,)
# Shape of X_test: (980, 11)
# Shape of y_test: (980,)

# %% [markdown]
# ### **Task 2**
#
# As a first step, we construct a trivial model that returns the mean of the y-values in the training data for any wine record in X. We use this trivial model as a baseline. The linear regression models we build later should perform better than this trivial model.

# %%
#@title
# Task 2: implement the trivial predictor
# The function computes the average value of y on the training label values
def compute_average(y_train):
    # The code below is just for compilation. 
    # You need to delete it and write your own code.
    ###################################################
    ##### YOUR CODE STARTS HERE #######################
    ###################################################
    # Hint: return the mean of y_train

    return sum(y_train)/len(y_train)
    ###################################################
    ##### YOUR CODE ENDS HERE #########################
    ###################################################

y_train_avg = compute_average(y_train)
print("The average of the y-values in the training data is {}".format(y_train_avg)) 

# The trivial predictor returns the average value.
def trivial_predictor(X_test, y_train_avg):
  return y_train_avg
# Out:
# The average of the y-values in the training data is 5.878764675855028

# %% [markdown]
# ### **Task 3**
# We next evaluate the trivial predictor on the training data and test data.
# We use mean squared error (MSE) to measure the performance of the predictor.
# The task is to implement a function that reports the mean squared error of the given predictor on the given data.

# %%
# We next test our trivial predictor on the training data and test data. 
# Implement a function that can report the mean squared error 
# of a predictor on the given data
# Input: data and predictor
# Output: mean squared error of the predictor on the given data
def test_predictor(X, y, predictor: callable=None):
    # Apply the predictor to each row of the matrix X to get the predictions
    y_predicted = np.apply_along_axis(predictor, 1, X)

    # TODO: compute the mean squared error of y
    # The code below is just for compilation. 
    # You need to delete it and write your own code.
    ###################################################
    ##### YOUR CODE STARTS HERE #######################
    ###################################################
    i=0
    mse=0
    for value in y:
      mse = mse + (value-y_predicted[i])*(value-y_predicted[i])
      i=i+1
    mse=mse/len(y)
    ###################################################
    ##### YOUR CODE ENDS HERE #########################
    ###################################################
    
    return mse

# use the function test_predictor to test the trivial predictor
# we use the lambda function here to pass the function trivial predictor to the function test_predictor.
mse_trivial_predictor_train = test_predictor(X_train, y_train, lambda x: trivial_predictor(x, y_train_avg))
mse_trivial_predictor_test = test_predictor(X_test, y_test, lambda x: trivial_predictor(x, y_train_avg))

# Report the result
print('Trivial Predictor')
print('--------------------------------------------------------------------------------\n')
print('MSE (Training) = %.4f' % mse_trivial_predictor_train)
print('MSE (Testing)  = %.4f' % mse_trivial_predictor_test)
# Out:
# Trivial Predictor
# --------------------------------------------------------------------------------
#
# MSE (Training) = 0.7768
# MSE (Testing)  = 0.8139

# %% [markdown]
# ## Train the Linear Model Using the Least Squares Method
#
# Let's next train a linear regression model on the training data.
# We use the closed form solution of the least squares estimate to compute the parameters of the linear regression model.
# This model should perform better than the trivial predictor.

# %% [markdown]
# ### **Task 4**
# Before training the model, we need to standardize the data, i.e., transform the data so that every feature has mean 0 and variance 1.
#
# https://en.wikipedia.org/wiki/Standard_score
#
# We first standardize the training data, and then apply the same transformation to the test data. That is, standardize the test data using the means and the standard deviations of the training data.

# %%
# The task is to implement a function that can standardize the data and returns the mean and std of the data.
# Input: training data
# Output: standardize training data, standard deviations and means
def standardize_data(X):
    # TODO: compute the means and standard deviations of the data, and standardize the data
    # The code below is just for compilation. 
    # You need to replace it by your own code.
    ###################################################
    ##### YOUR CODE STARTS HERE #######################
    ###################################################

    mean = X.mean(axis=0)
    std = X.std(axis=0)
    X_std = (X-mean) / std
    ###################################################
    ##### YOUR CODE ENDS HERE #########################
    ###################################################
    
    return X_std, mean, std

# Standardize the training data and store the means and the stds 
X_train_std, X_train_mean, X_train_std_div = standardize_data(X_train)
print("X_train_std:", X_train_std.shape)
print("Mean:", X_train_mean)
print("Standard deviation:", X_train_std_div)
# Out:
# X_train_std: (3918, 11)
# Mean: [6.85427514e+00 2.78390761e-01 3.34892802e-01 6.42623788e+00
#  4.58213374e-02 3.53263144e+01 1.38513272e+02 9.94040729e-01
#  3.18647524e+00 4.89055641e-01 1.05115799e+01]
# Standard deviation: [8.39100902e-01 9.95630176e-02 1.24249975e-01 5.06377532e+00
#  2.16660282e-02 1.71004677e+01 4.23956179e+01 2.97972269e-03
#  1.49949475e-01 1.12992053e-01 1.22536544e+00]

# %%
# TODO: Standardize the test data using the means and standrad deviations of the training data
###################################################
##### YOUR CODE STARTS HERE #######################
###################################################
X_test_std = (X_test-X_train_mean)/X_train_std_div
print(X_test_std.shape)
###################################################
##### YOUR CODE ENDS HERE #########################
###################################################
# Out:
# (980, 11)

# %% [markdown]
# ### **Task 5**
# Let's now train the linear model using the least-squares method.
# We need to add the bias term to the matrix X.

# %%
# The task is to implement the function that adds a column of ones to the first column of X
def expand_with_ones(X):
    # TODO: add a column of ones to the front of the input matrix
    # The code below is just for compilation. 
    # You need to replace it by your own code.
    ###################################################
    ##### YOUR CODE STARTS HERE #######################
    ###################################################
    X_out = np.c_[np.ones((len(X),1)),X]
    return X_out
    ###################################################
    ##### YOUR CODE ENDS HERE #########################
    ###################################################

# Train the linear model using the least-squares method
# The task is to implement the function that computes the parameters
def least_squares_compute_parameters(X_input, y):
    # add the bias column to the data
    X = expand_with_ones(X_input)

    # TODO: compute the parameters based on the expanded X and y using the least-squares method
    # The code below is just for compilation. 
    # You need to replace it by your own code.
    ###################################################
    ##### YOUR CODE STARTS HERE #######################
    ###################################################
    from numpy.linalg import inv
    XtX = np.dot(X.transpose(),X) # X_transpose * X
    XtX_inv = inv(XtX)            # Inverse of X_transpose * X
    Xty = np.dot(X.transpose(),y) # X_transpose * y
    w = np.dot(XtX_inv, Xty)
    return w
    ###################################################
    ##### YOUR CODE ENDS HERE #########################
    ###################################################

# Apply the function to train the linear model
w = least_squares_compute_parameters(X_train_std, y_train) 
print("w:", w.shape)
# Out:
# w: (12,)

# %% [markdown]
# After computing the parameters,
# we can build the linear model predictor.
# The predictor takes as input the computed parameters and the data, and predicts the labels for the input data.

# %%
# Implement the linear model predictor
# Input: test data and parameters
# Output: predicted values
def linear_model_predictor(X, w):
    # TODO: predict the labels for the input data
    # The code below is just for compilation. 
    # You need to replace it by your own code.
    ###################################################
    ##### YOUR CODE STARTS HERE #######################
    ###################################################
    y = np.dot(X,w)
    return y
    ###################################################
    ##### YOUR CODE ENDS HERE #########################
    ###################################################

# %% [markdown]
# Evaluate our linear regression model predictor on the test data.

# %%
# use the function test_predictor to evaluate the linear model predictor
mse_linear_model_predictor = test_predictor(expand_with_ones(X_test_std), y_test, lambda x: linear_model_predictor(x, w))
print("Mean squared error is {}".format(mse_linear_model_predictor))
# Out:
# Mean squared error is 0.5607292042283473

# %% [markdown]
# ## Learning Curves
#
# Let us check if the linear model is overfitting or underfitting. Since the dataset is somewhat large and there are only 11 features, the model shouldn't be overfitting.
# To check it, we use the learning curves: we plot how the performance of the model changes when it is trained with increasingly more data.

# %% [markdown]
# ### **Task 6**
#
# Let's first implement a function that comprises what we have implemented above.
# The function takes as inputs the data and the split coefficient, and then
# 1. standardizes the data,
# 2. trains the linear model (compute the parameters), and
# 3. reports the MSE of the linear model predictor on both the training and the test data.

# %%
# Input: training data and test data
# Output: mse of the linear model predictor on both the training and test data
def train_and_test(X_train, y_train, X_test, y_test):
    # TODO: implement the function 
    # The code below is just for compilation. 
    # You need to replace it by your own code.
    ###################################################
    ##### YOUR CODE STARTS HERE #######################
    ###################################################
    # Hints: use the functions you have implemented
    X_train_std, X_train_mean, X_train_std_div = standardize_data(X_train)
    X_test_std = (X_test-X_train_mean)/X_train_std_div
    w = least_squares_compute_parameters(X_train_std, y_train) 

    mse_train = test_predictor(expand_with_ones(X_train_std), y_train, lambda x: linear_model_predictor(x, w))
    mse_test = test_predictor(expand_with_ones(X_test_std), y_test, lambda x: linear_model_predictor(x, w))
    return mse_train, mse_test
    ###################################################
    ##### YOUR CODE ENDS HERE #########################
    ###################################################

mse_train, mse_test = train_and_test(X_train, y_train, X_test, y_test)
print('Linear Model')
print('-----------------------\n')
print('MSE (Training) = %.4f' % mse_train)
print('MSE (Testing)  = %.4f' % mse_test)
# Out:
# Linear Model
# -----------------------
#
# MSE (Training) = 0.5640
# MSE (Testing)  = 0.5607

# %% [markdown]
# ### **Task 7**
#
# We are now ready to plot the learning curves.
#
# We train a list of models on the increasingly more training data ([20, 40, ..., 600] data records).
# For each of such model, we compute the MSEs of the model on both the training data and the test data, and store the MSEs in the lists `mse_train_v` and `mse_test`, respectively.
# The code provided below will then plot the learning curves.
#
# Your plot should show the two curves (roughly) meet at round 150 training data records.

# %%
mse_train_v = []
mse_test_v = []

TRAINING_SIZE_MAX = 601
TRAINING_SIZE_MIN = 20

# compute the MSE over data with sizes from TRAINING_SIZE_MIN to TRAINING_SIZE_MAX with increasing step 20
for train_size in range(TRAINING_SIZE_MIN, TRAINING_SIZE_MAX, 20):
    # TODO: 
    #   1. use the first train_size data records from the X_train and y_train as the training data
    #   2. train and compute the MSE on both training and test data using the train_and_test function
    #   3. add the computed MSE to the lists mse_train_v and mse_test_v
    # The code below is just for compilation. 
    # You need to replace it by your own code.
    ###################################################
    ##### YOUR CODE STARTS HERE #######################
    ###################################################

    mse_train, mse_test = train_and_test(X_train[0:train_size, :], y_train[0:train_size], X_test, y_test)
    mse_train_v.append(mse_train)
    mse_test_v.append(mse_test)      

    ###################################################
    ##### YOUR CODE ENDS HERE #########################
    ###################################################
    

# The below code generates the learning curves plot
plt.plot(np.arange(TRAINING_SIZE_MIN, TRAINING_SIZE_MAX, 20), mse_train_v, 'r--', label="Training Error")
plt.plot(np.arange(TRAINING_SIZE_MIN, TRAINING_SIZE_MAX, 20), mse_test_v, 'b-', label="Test Error")
plt.legend(loc="upper right")
plt.xlabel('Dataset Size')
plt.ylabel('Mean Squared Error')
plt.show()

# %% [markdown]
# ## Polynomial Basis Expansion and Regularisation
#
# In this part, we will improve the linear regression model by basis expansion and regularization:
# 1. apply the degree 2 basis expansion to the data,
# 2. build the Ridge and Lasso models and
# 3. perform hyperparameter optimization using the validation data.
#
# For the hyperparameter optimization, you should set the last 20% of the training data for the purpose of validation and try lambda values in the range [10^-4, 10^-3, 10^-2, 10^-1, 1, 10, 100].
#
# We will use the scikit-learn library. We have imported the necessary functions for you. You can import other scikit-learn functions if you think they are useful. The documentation is available here: http://scikit-learn.org/stable/modules/classes.html

# %%
# import the preprocessing libs for standarization and basis expansion
from sklearn.preprocessing import StandardScaler, PolynomialFeatures 

# Ridge and Lasso linear model
from sklearn.linear_model import Ridge, Lasso

# %% [markdown]
# ### **Task 8**
# Let's implement the function for expanding the basis of the dataset.
#
# Hints: use `PolynomialFeatures`

# %%
def expand_basis(X, degree):
    # TODO: expand the basis of X for the input degree
    # The code below is just for compilation. 
    # You need to replace it by your own code.
    ###################################################
    ##### YOUR CODE STARTS HERE #######################
    ###################################################
    # Hints: use the function PolynomialFeatures

    trans = PolynomialFeatures(degree)
    X = trans.fit_transform(X)
    return X
    ###################################################
    ##### YOUR CODE ENDS HERE #########################
    ###################################################

# %% [markdown]
# ### **Task 9**
# We need to prepare the data.
# We first expand and standardize the data,
# and then split the training data to training data and validation data.
# We use the last 20% of the training data as the validation data.
#
# Hints: use `StandardScaler` and `std_scaler` to standardize the data

# %%
def prepare_data(X, y, degree):
    # TODO: the training, test and validation data using the expanded dataset.
    # The code below is just for compilation. 
    # You need to replace it by your own code.
    ###################################################
    ##### YOUR CODE STARTS HERE #######################
    ###################################################
    # Hints: follow the steps     
    # 1. split the data (X, y) into training data (X_train, y_train) and test data (X_test, y_test)
    # 2. standardize the training data and do the same transformation to the test data
    # 3. expand the basis of the training data and test data
    # 4. split the expanded training data into training data (X_train_n, y_train_n) and validation data (X_train_v, y_train_v)
    
    
    # training and test data
    X_train, y_train, X_test, y_test = split_data(X, y, 0.8)

    X_train, X_train_mean, X_train_std_div = standardize_data(X_train)
    X_test = (X_test-X_train_mean)/X_train_std_div

    X_train = expand_basis(X_train, degree)
    X_test = expand_basis(X_test, degree)

    # further split the training data to training and validation data
    X_train_n, y_train_n, X_train_v, y_train_v = split_data(X_train, y_train, 0.8)

    return X_train, y_train, X_train_n, y_train_n, X_train_v, y_train_v, X_test, y_test
    ###################################################
    ##### YOUR CODE ENDS HERE #########################
    ###################################################

X_train, y_train, X_train_n, y_train_n, X_train_v, y_train_v, X_test, y_test = prepare_data(X, y, 2) # here we expand the dataset with degree 2

# check the size of the splitted dataset
print("Shape of X_train_n:", X_train_n.shape) # expected output (3134, 78)
print("Shape of y_train_n:", y_train_n.shape) # expected output (3134,)
print("Shape of X_train_v:", X_train_v.shape) # expected output (784, 78)
print("Shape of y_train_v:", y_train_v.shape) # expected output (784,)
print("Shape of X_test:", X_test.shape) # expected output (980, 78)
print("Shape of y_test:", y_test.shape) # expected output (980,)
# Out:
# Shape of X_train_n: (3134, 78)
# Shape of y_train_n: (3134,)
# Shape of X_train_v: (784, 78)
# Shape of y_train_v: (784,)
# Shape of X_test: (980, 78)
# Shape of y_test: (980,)

# %% [markdown]
# ### **Task 10**
# We have prepared the training data and the validation data.
# We can now use the validation data to select the optimal hyperparameters for the Ridge and Lasso models.
# We use the Ridge and Lasso models from scikit-learn: https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.Ridge.html
#
# We train Ridge or Lasso models with different lambda values and check their performance on the validation data, and select the lambda values that yield the best performance.

# %%
# The function takes the training and validation data as inputs, and 
# returns the lambda value that results the minimal mse
# We use is_ridge to indicate which the model is considered.
# is_ridge = True indicates Ridge while is_ridge = False indicates Lasso
def choose_hyper_param(X_train_n, y_train_n, X_train_v, y_train_v, is_ridge: bool):
    mse_arr = []
    lam_arr = []

    # Try lambda values from 10^-4 to 10^2. 
    # Record the mse and the lambda values in mse_arr and lam_arr
    # The code below is just for compilation. 
    # You need to replace it by your own code.
    ###################################################
    ##### YOUR CODE STARTS HERE #######################
    ###################################################
    from sklearn.metrics import mean_squared_error

    for pow_lam in range(-4, 3):
        lam = 10 ** pow_lam
        if is_ridge:
          model = Ridge(alpha=lam)
          model.fit(X_train_n, y_train_n)
          pred = model.predict(X_train_v)
        else:
          model = Lasso(alpha=lam)
          model.fit(X_train_n, y_train_n)
          pred = model.predict(X_train_v)
        mse = mean_squared_error(y_train_v,pred)
        mse_arr.append(mse) 
        lam_arr.append(lam) 
    ###################################################
    ##### YOUR CODE ENDS HERE #########################
    ###################################################


    # get the index of the lambda value that has the minimal use
    lambda_idx_min = np.argmin(np.array(mse_arr))

    # plot of the lambda values and their mse
    plt.figure()
    plt.semilogx(lam_arr, mse_arr)

    # return the optimal lambda value
    return lam_arr[lambda_idx_min], min(mse_arr)

# call the function to choose the lambda for Ridge and Lasso
lam_ridge, _ = choose_hyper_param(X_train_n, y_train_n, X_train_v, y_train_v, True)
lam_lasso, _ = choose_hyper_param(X_train_n, y_train_n, X_train_v, y_train_v, False)

print("Ridge lambda:", lam_ridge)
print("Lasso lambda:", lam_lasso)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.466e+02, tolerance: 2.424e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.957e+01, tolerance: 2.424e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# Ridge lambda: 10
# Lasso lambda: 0.001

# %% [markdown]
# ### **Task 11**:
# Once we get the optimal lambdas for Ridge and Lasso, we train these models using these lambdas on the full training data, and then report their performance.

# %%
# TODO: train the Ridge and Lasso models using the optimal parameters, and
#       report their MSE
###################################################
##### YOUR CODE STARTS HERE #######################
###################################################
# Hints: train these models on the full training data
from sklearn.metrics import mean_squared_error

model_ridge = Ridge(alpha=lam_ridge)
model_ridge.fit(X_train, y_train)
pred_ridge_train = model_ridge.predict(X_train)
pred_ridge_test = model_ridge.predict(X_test)

model_lasso = Lasso(alpha=lam_lasso)
model_lasso.fit(X_train, y_train)
pred_lasso_train = model_lasso.predict(X_train)
pred_lasso_test = model_lasso.predict(X_test)

mse_ridge_train = mean_squared_error(y_train, pred_ridge_train)
mse_ridge_test = mean_squared_error(y_test, pred_ridge_test)
mse_lasso_train = mean_squared_error(y_train, pred_lasso_train)
mse_lasso_test = mean_squared_error(y_test, pred_lasso_test)
###################################################
##### YOUR CODE ENDS HERE #########################
###################################################

# Report the result
print('For Ridge Regression with using degree %d polynomial expansion and lambda = %.4f' % (2, lam_ridge))
print('--------------------------------------------------------------------------------\n')
print('MSE (Training) = %.4f' % mse_ridge_train)
print('MSE (Testing)  = %.4f' % mse_ridge_test)

print('\n\nFor Lasso with using degree %d polynomial expansion and lambda = %.4f' % (2, lam_lasso))
print('---------------------------------------------------------------------\n')
print('MSE (Training) = %.4f' % mse_lasso_train)
print('MSE (Testing)  = %.4f' % mse_lasso_test)
# Out:
# For Ridge Regression with using degree 2 polynomial expansion and lambda = 10.0000
# --------------------------------------------------------------------------------
#
# MSE (Training) = 0.4955
# MSE (Testing)  = 0.5117
#
#
# For Lasso with using degree 2 polynomial expansion and lambda = 0.0010
# ---------------------------------------------------------------------
#
# MSE (Training) = 0.4962
# MSE (Testing)  = 0.5098
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.057e-01, tolerance: 3.043e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive

# %% [markdown]
# ## Optional: Try Larger Degrees using K-fold Cross Validation

# %% [markdown]
# ### **Task 12**
# This is an optional task, which worths 5 bonus points.
#
# The task is to try basis expansions with higher degrees (up to degree 4) and find the degree that results the best performance.
# Instead of always using the same validation data, we use k-fold cross-validation to find the optimal hyperparameters.
#
# Your task is to report the optimal hyperparameters (the basis expansion degree and the lambdas) and the MSEs of the Ridge and Lasso when using these optimal hyperparameters.
#
# Hints: Use `KFold` to do this automatically.

# %%
from typing import List, Dict
import json
# KFold
from sklearn.model_selection import KFold

###################################################
##### YOUR CODE STARTS HERE #######################
###################################################

### attention, this may take a while

"""
Because it was not clear if we should use the parameters with the minimal
mse on X_test in one fold or the parameters with the lowest mean over all folds,
we tried both.

Taking the parameters with the minimal X_test on one fold yielded better results.
"""


size = int(X.shape[0] * 0.8)
# training data
X_train = X[:size, :]
y_train = y[:size]

# test data
X_test = X[size:, :]
y_test = y[size:]

scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

from dataclasses import dataclass

@dataclass
class HyperParameter:
    degree: int
    lam: float

    def __str__(self) -> str:
        return f"HyperParameter[degree={self.degree}, lam={self.lam}]"


@dataclass
class ParamSearchResult:
    fold: int
    hyper_params: HyperParameter
    mse_validation: float
    mse_test: float

@dataclass
class FoldResult:
    ridge: ParamSearchResult
    lasso: ParamSearchResult

fold_count = 5
k_fold = KFold(fold_count)

fold_results : List[Dict[str, FoldResult]] = [{} for i in range(fold_count + 1)]

min_lasso_mse = 10000
min_ridge_mse = 10000

best_lasso : ParamSearchResult = None
best_ridge : ParamSearchResult = None

iteration_results = {}


iteration = 0
for train_indexes, test_indexes in k_fold.split(X_train):
    iteration+=1
    fold_train = X_train[train_indexes]
    fold_train_labels = y_train[train_indexes]
    fold_validate = X_train[test_indexes]
    fold_validate_labels = y_train[test_indexes]

    iteration_min_lasso_mse = 10000
    iteration_min_ridge_mse = 10000

    iteration_best_lasso : ParamSearchResult = None
    iteration_best_ridge : ParamSearchResult = None


    for degree in range(1, 5):
        X_train_expanded = expand_basis(fold_train, degree)
        X_validate_expanded = expand_basis(fold_validate, degree)

        for pow_lam in range(-4, 3):
            lam = 10 ** pow_lam
            def evaluate_model(model):
                model.fit(X_train_n, y_train_n)
                predicted_v = model.predict(X_train_v)
                mse = mean_squared_error(y_train_v, predicted_v)
                return mse
            ridge_mse = evaluate_model(Ridge(alpha=lam))
            ridge_result = ParamSearchResult(iteration, HyperParameter(degree, lam), ridge_mse, None)

            lasso_mse = evaluate_model(Lasso(alpha=lam))
            lasso_result = ParamSearchResult(iteration, HyperParameter(degree, lam), lasso_mse, None)

            fold_result = FoldResult(ridge_result, lasso_result)
            fold_results[iteration][HyperParameter(degree, lam).__str__()] = FoldResult(ridge_result, lasso_result)

        lasso_lambda, lasso_mse = choose_hyper_param(X_train_expanded, fold_train_labels, X_validate_expanded, fold_validate_labels, False)
        if lasso_mse < iteration_min_lasso_mse:
            iteration_min_lasso_mse = lasso_mse
            iteration_best_lasso = ParamSearchResult(iteration, HyperParameter(degree, lasso_lambda), lasso_mse, None)

        ridge_lambda, ridge_mse = choose_hyper_param(X_train_expanded, fold_train_labels, X_validate_expanded, fold_validate_labels, True)
        if ridge_mse < iteration_min_ridge_mse:
            iteration_min_ridge_mse = ridge_mse
            iteration_best_ridge = ParamSearchResult(iteration, HyperParameter(degree, ridge_lambda), ridge_mse, None)

    fold_result = FoldResult(None, None)
    def evaluate_lasso():
        X_train_expanded = expand_basis(X_train, iteration_best_lasso.hyper_params.degree)
        X_test_expanded = expand_basis(X_test, iteration_best_lasso.hyper_params.degree)
        lasso = Lasso(iteration_best_lasso.hyper_params.lam)
        lasso.fit(X_train_expanded, y_train)
        mse_test = mean_squared_error(y_test, lasso.predict(X_test_expanded))
        iteration_best_lasso.mse_test = mse_test
        fold_result.lasso = iteration_best_lasso
        iteration_results[iteration] = iteration_best_lasso
        if mse_test < min_lasso_mse:
            return iteration_best_lasso, mse_test
        else:
            return best_lasso, min_lasso_mse
    best_lasso, min_lasso_mse = evaluate_lasso()

    def evaluate_ridge():
        X_train_expanded = expand_basis(X_train, iteration_best_ridge.hyper_params.degree)
        X_test_expanded = expand_basis(X_test, iteration_best_ridge.hyper_params.degree)
        ridge = Ridge(iteration_best_ridge.hyper_params.lam)
        ridge.fit(X_train_expanded, y_train)
        mse_test = mean_squared_error(y_test, ridge.predict(X_test_expanded))
        iteration_best_ridge.mse_test = mse_test
        fold_result.ridge = iteration_best_ridge
        iteration_results[iteration] = iteration_best_ridge
        if mse_test < min_ridge_mse:
            return iteration_best_ridge, mse_test
        else:
            return best_ridge, min_ridge_mse
    best_ridge, min_ridge_mse = evaluate_ridge()

    iteration_results[iteration] = fold_result
print('\n\n\n')
print(f'Best lasso parameters: ${best_lasso}')
print(f'Best ridge parameters: ${best_ridge}')

###################################################
##### YOUR CODE ENDS HERE #########################
###################################################
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.466e+02, tolerance: 2.424e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.957e+01, tolerance: 2.424e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.466e+02, tolerance: 2.424e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.957e+01, tolerance: 2.424e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.838e+02, tolerance: 2.429e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.208e+00, tolerance: 2.429e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.466e+02, tolerance: 2.424e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.957e+01, tolerance: 2.424e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.250e+02, tolerance: 2.429e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.386e+02, tolerance: 2.429e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.270e+00, tolerance: 2.429e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.466e+02, tolerance: 2.424e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.957e+01, tolerance: 2.424e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.405e+02, tolerance: 2.429e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.377e+02, tolerance: 2.429e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.490e+02, tolerance: 2.429e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.443e+02, tolerance: 2.429e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.057e-01, tolerance: 3.043e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.466e+02, tolerance: 2.424e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.957e+01, tolerance: 2.424e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.466e+02, tolerance: 2.424e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.957e+01, tolerance: 2.424e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.784e+00, tolerance: 2.481e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.466e+02, tolerance: 2.424e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.957e+01, tolerance: 2.424e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.335e+02, tolerance: 2.481e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.653e+02, tolerance: 2.481e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.466e+02, tolerance: 2.424e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.957e+01, tolerance: 2.424e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.240e+02, tolerance: 2.481e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.274e+02, tolerance: 2.481e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.044e+02, tolerance: 2.481e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.673e+02, tolerance: 2.481e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.057e-01, tolerance: 3.043e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.466e+02, tolerance: 2.424e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.957e+01, tolerance: 2.424e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.466e+02, tolerance: 2.424e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.957e+01, tolerance: 2.424e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.090e+02, tolerance: 2.422e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.466e+02, tolerance: 2.424e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.957e+01, tolerance: 2.424e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.275e+02, tolerance: 2.422e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.457e+02, tolerance: 2.422e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.865e+00, tolerance: 2.422e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:40: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:40: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.466e+02, tolerance: 2.424e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.957e+01, tolerance: 2.424e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.275e+02, tolerance: 2.422e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.336e+02, tolerance: 2.422e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.475e+02, tolerance: 2.422e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.086e+02, tolerance: 2.422e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:40: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:40: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.057e-01, tolerance: 3.043e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.466e+02, tolerance: 2.424e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.957e+01, tolerance: 2.424e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:40: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:40: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.466e+02, tolerance: 2.424e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.957e+01, tolerance: 2.424e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.761e+02, tolerance: 2.415e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.845e+00, tolerance: 2.415e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:40: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:40: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.466e+02, tolerance: 2.424e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.957e+01, tolerance: 2.424e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.267e+02, tolerance: 2.415e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.359e+02, tolerance: 2.415e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.593e+01, tolerance: 2.415e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:40: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:40: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.466e+02, tolerance: 2.424e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.957e+01, tolerance: 2.424e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.181e+02, tolerance: 2.415e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.053e+02, tolerance: 2.415e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.444e+02, tolerance: 2.415e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.876e+02, tolerance: 2.415e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:40: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:40: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.466e+02, tolerance: 2.424e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.957e+01, tolerance: 2.424e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:40: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:40: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.466e+02, tolerance: 2.424e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.957e+01, tolerance: 2.424e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.487e+02, tolerance: 2.425e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.118e+01, tolerance: 2.425e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:40: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:40: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.466e+02, tolerance: 2.424e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.957e+01, tolerance: 2.424e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.318e+02, tolerance: 2.425e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.095e+02, tolerance: 2.425e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.012e+00, tolerance: 2.425e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:40: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:40: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.466e+02, tolerance: 2.424e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.957e+01, tolerance: 2.424e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.282e+02, tolerance: 2.425e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.016e+02, tolerance: 2.425e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.673e+02, tolerance: 2.425e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.192e+02, tolerance: 2.425e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:40: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:40: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.458e+02, tolerance: 3.043e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# Best lasso parameters: $ParamSearchResult(fold=1, hyper_params=HyperParameter(degree=2, lam=0.001), mse_validation=0.5351392351455678, mse_test=0.5097659028396889)
# Best ridge parameters: $ParamSearchResult(fold=2, hyper_params=HyperParameter(degree=2, lam=10), mse_validation=0.4865169951644061, mse_test=0.5116677456584303)

# %%
print(json.dumps(list(iteration_results.values()), default=lambda x: x.__dict__, indent=4))

print(json.dumps(fold_results, default=lambda x: x.__dict__, indent=4))
# Out:
# [
#     {
#         "ridge": {
#             "fold": 1,
#             "hyper_params": {
#                 "degree": 2,
#                 "lam": 1
#             },
#             "mse_validation": 0.536657830203277,
#             "mse_test": 0.5125211633574805
#         },
#         "lasso": {
#             "fold": 1,
#             "hyper_params": {
#                 "degree": 2,
#                 "lam": 0.001
#             },
#             "mse_validation": 0.5351392351455678,
#             "mse_test": 0.5097659028396889
#         }
#     },
#     {
#         "ridge": {
#             "fold": 2,
#             "hyper_params": {
#                 "degree": 2,
#                 "lam": 10
#             },
#             "mse_validation": 0.4865169951644061,
#             "mse_test": 0.5116677456584303
#         },
#         "lasso": {
#             "fold": 2,
#             "hyper_params": {
#                 "degree": 2,
#                 "lam": 0.001
#             },
#             "mse_validation": 0.4936605572200646,
#             "mse_test": 0.5097659028396889
#         }
#     },
#     {
#         "ridge": {
#             "fold": 3,
#             "hyper_params": {
#                 "degree": 2,
#                 "lam": 10
#             },
#             "mse_validation": 0.5184611626046444,
#             "mse_test": 0.5116677456584303
#         },
#         "lasso": {
#             "fold": 3,
#             "hyper_params": {
#                 "degree": 2,
#                 "lam": 0.001
#             },
#             "mse_validation": 0.515888221431562,
#             "mse_test": 0.5097659028396889
#         }
#     },
#     {
#         "ridge": {
#             "fold": 4,
#             "hyper_params": {
#                 "degree": 1,
#                 "lam": 10
#             },
#             "mse_validation": 0.5794415547232569,
#             "mse_test": 0.5608929799915933
#         },
#         "lasso": {
#             "fold": 4,
#             "hyper_params": {
#                 "degree": 1,
#                 "lam": 0.001
#             },
#             "mse_validation": 0.5793001096815261,
#             "mse_test": 0.5610049030906814
#         }
#     },
#     {
#         "ridge": {
#             "fold": 5,
#             "hyper_params": {
#                 "degree": 2,
#                 "lam": 10
#             },
#             "mse_validation": 0.5279149085098362,
#             "mse_test": 0.5116677456584303
#         },
#         "lasso": {
#             "fold": 5,
#             "hyper_params": {
#                 "degree": 4,
#                 "lam": 0.01
#             },
#             "mse_validation": 0.5037502223431011,
#             "mse_test": 0.6226036660105059
#         }
#     }
# ]
# [
#     {},
#     {
#         "HyperParameter[degree=1, lam=0.0001]": {
#             "ridge": {
#                 "fold": 1,
#                 "hyper_params": {
#                     "degree": 1,
#                     "lam": 0.0001
#                 },
#                 "mse_validation": 0.5290507090092169,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 1,
#                 "hyper_params": {
#                     "degree": 1,
#                     "lam": 0.0001
#                 },
#                 "mse_validation": 0.5266160477446193,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=1, lam=0.001]": {
#             "ridge": {
#                 "fold": 1,
#                 "hyper_params": {
#                     "degree": 1,
#                     "lam": 0.001
#                 },
#                 "mse_validation": 0.5290498523406076,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 1,
#                 "hyper_params": {
#                     "degree": 1,
#                     "lam": 0.001
#                 },
#                 "mse_validation": 0.5264677214248558,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=1, lam=0.01]": {
#             "ridge": {
#                 "fold": 1,
#                 "hyper_params": {
#                     "degree": 1,
#                     "lam": 0.01
#                 },
#                 "mse_validation": 0.5290413166276253,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 1,
#                 "hyper_params": {
#                     "degree": 1,
#                     "lam": 0.01
#                 },
#                 "mse_validation": 0.5460919532234378,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=1, lam=0.1]": {
#             "ridge": {
#                 "fold": 1,
#                 "hyper_params": {
#                     "degree": 1,
#                     "lam": 0.1
#                 },
#                 "mse_validation": 0.5289589573159403,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 1,
#                 "hyper_params": {
#                     "degree": 1,
#                     "lam": 0.1
#                 },
#                 "mse_validation": 0.6224176842982749,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=1, lam=1]": {
#             "ridge": {
#                 "fold": 1,
#                 "hyper_params": {
#                     "degree": 1,
#                     "lam": 1
#                 },
#                 "mse_validation": 0.5283608768411331,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 1,
#                 "hyper_params": {
#                     "degree": 1,
#                     "lam": 1
#                 },
#                 "mse_validation": 0.7906338833411302,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=1, lam=10]": {
#             "ridge": {
#                 "fold": 1,
#                 "hyper_params": {
#                     "degree": 1,
#                     "lam": 10
#                 },
#                 "mse_validation": 0.527818877346802,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 1,
#                 "hyper_params": {
#                     "degree": 1,
#                     "lam": 10
#                 },
#                 "mse_validation": 0.7906338833411302,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=1, lam=100]": {
#             "ridge": {
#                 "fold": 1,
#                 "hyper_params": {
#                     "degree": 1,
#                     "lam": 100
#                 },
#                 "mse_validation": 0.5352806143692452,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 1,
#                 "hyper_params": {
#                     "degree": 1,
#                     "lam": 100
#                 },
#                 "mse_validation": 0.7906338833411302,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=2, lam=0.0001]": {
#             "ridge": {
#                 "fold": 1,
#                 "hyper_params": {
#                     "degree": 2,
#                     "lam": 0.0001
#                 },
#                 "mse_validation": 0.5290507090092169,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 1,
#                 "hyper_params": {
#                     "degree": 2,
#                     "lam": 0.0001
#                 },
#                 "mse_validation": 0.5266160477446193,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=2, lam=0.001]": {
#             "ridge": {
#                 "fold": 1,
#                 "hyper_params": {
#                     "degree": 2,
#                     "lam": 0.001
#                 },
#                 "mse_validation": 0.5290498523406076,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 1,
#                 "hyper_params": {
#                     "degree": 2,
#                     "lam": 0.001
#                 },
#                 "mse_validation": 0.5264677214248558,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=2, lam=0.01]": {
#             "ridge": {
#                 "fold": 1,
#                 "hyper_params": {
#                     "degree": 2,
#                     "lam": 0.01
#                 },
#                 "mse_validation": 0.5290413166276253,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 1,
#                 "hyper_params": {
#                     "degree": 2,
#                     "lam": 0.01
#                 },
#                 "mse_validation": 0.5460919532234378,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=2, lam=0.1]": {
#             "ridge": {
#                 "fold": 1,
#                 "hyper_params": {
#                     "degree": 2,
#                     "lam": 0.1
#                 },
#                 "mse_validation": 0.5289589573159403,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 1,
#                 "hyper_params": {
#                     "degree": 2,
#                     "lam": 0.1
#                 },
#                 "mse_validation": 0.6224176842982749,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=2, lam=1]": {
#             "ridge": {
#                 "fold": 1,
#                 "hyper_params": {
#                     "degree": 2,
#                     "lam": 1
#                 },
#                 "mse_validation": 0.5283608768411331,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 1,
#                 "hyper_params": {
#                     "degree": 2,
#                     "lam": 1
#                 },
#                 "mse_validation": 0.7906338833411302,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=2, lam=10]": {
#             "ridge": {
#                 "fold": 1,
#                 "hyper_params": {
#                     "degree": 2,
#                     "lam": 10
#                 },
#                 "mse_validation": 0.527818877346802,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 1,
#                 "hyper_params": {
#                     "degree": 2,
#                     "lam": 10
#                 },
#                 "mse_validation": 0.7906338833411302,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=2, lam=100]": {
#             "ridge": {
#                 "fold": 1,
#                 "hyper_params": {
#                     "degree": 2,
#                     "lam": 100
#                 },
#                 "mse_validation": 0.5352806143692452,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 1,
#                 "hyper_params": {
#                     "degree": 2,
#                     "lam": 100
#                 },
#                 "mse_validation": 0.7906338833411302,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=3, lam=0.0001]": {
#             "ridge": {
#                 "fold": 1,
#                 "hyper_params": {
#                     "degree": 3,
#                     "lam": 0.0001
#                 },
#                 "mse_validation": 0.5290507090092169,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 1,
#                 "hyper_params": {
#                     "degree": 3,
#                     "lam": 0.0001
#                 },
#                 "mse_validation": 0.5266160477446193,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=3, lam=0.001]": {
#             "ridge": {
#                 "fold": 1,
#                 "hyper_params": {
#                     "degree": 3,
#                     "lam": 0.001
#                 },
#                 "mse_validation": 0.5290498523406076,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 1,
#                 "hyper_params": {
#                     "degree": 3,
#                     "lam": 0.001
#                 },
#                 "mse_validation": 0.5264677214248558,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=3, lam=0.01]": {
#             "ridge": {
#                 "fold": 1,
#                 "hyper_params": {
#                     "degree": 3,
#                     "lam": 0.01
#                 },
#                 "mse_validation": 0.5290413166276253,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 1,
#                 "hyper_params": {
#                     "degree": 3,
#                     "lam": 0.01
#                 },
#                 "mse_validation": 0.5460919532234378,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=3, lam=0.1]": {
#             "ridge": {
#                 "fold": 1,
#                 "hyper_params": {
#                     "degree": 3,
#                     "lam": 0.1
#                 },
#                 "mse_validation": 0.5289589573159403,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 1,
#                 "hyper_params": {
#                     "degree": 3,
#                     "lam": 0.1
#                 },
#                 "mse_validation": 0.6224176842982749,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=3, lam=1]": {
#             "ridge": {
#                 "fold": 1,
#                 "hyper_params": {
#                     "degree": 3,
#                     "lam": 1
#                 },
#                 "mse_validation": 0.5283608768411331,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 1,
#                 "hyper_params": {
#                     "degree": 3,
#                     "lam": 1
#                 },
#                 "mse_validation": 0.7906338833411302,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=3, lam=10]": {
#             "ridge": {
#                 "fold": 1,
#                 "hyper_params": {
#                     "degree": 3,
#                     "lam": 10
#                 },
#                 "mse_validation": 0.527818877346802,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 1,
#                 "hyper_params": {
#                     "degree": 3,
#                     "lam": 10
#                 },
#                 "mse_validation": 0.7906338833411302,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=3, lam=100]": {
#             "ridge": {
#                 "fold": 1,
#                 "hyper_params": {
#                     "degree": 3,
#                     "lam": 100
#                 },
#                 "mse_validation": 0.5352806143692452,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 1,
#                 "hyper_params": {
#                     "degree": 3,
#                     "lam": 100
#                 },
#                 "mse_validation": 0.7906338833411302,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=4, lam=0.0001]": {
#             "ridge": {
#                 "fold": 1,
#                 "hyper_params": {
#                     "degree": 4,
#                     "lam": 0.0001
#                 },
#                 "mse_validation": 0.5290507090092169,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 1,
#                 "hyper_params": {
#                     "degree": 4,
#                     "lam": 0.0001
#                 },
#                 "mse_validation": 0.5266160477446193,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=4, lam=0.001]": {
#             "ridge": {
#                 "fold": 1,
#                 "hyper_params": {
#                     "degree": 4,
#                     "lam": 0.001
#                 },
#                 "mse_validation": 0.5290498523406076,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 1,
#                 "hyper_params": {
#                     "degree": 4,
#                     "lam": 0.001
#                 },
#                 "mse_validation": 0.5264677214248558,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=4, lam=0.01]": {
#             "ridge": {
#                 "fold": 1,
#                 "hyper_params": {
#                     "degree": 4,
#                     "lam": 0.01
#                 },
#                 "mse_validation": 0.5290413166276253,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 1,
#                 "hyper_params": {
#                     "degree": 4,
#                     "lam": 0.01
#                 },
#                 "mse_validation": 0.5460919532234378,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=4, lam=0.1]": {
#             "ridge": {
#                 "fold": 1,
#                 "hyper_params": {
#                     "degree": 4,
#                     "lam": 0.1
#                 },
#                 "mse_validation": 0.5289589573159403,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 1,
#                 "hyper_params": {
#                     "degree": 4,
#                     "lam": 0.1
#                 },
#                 "mse_validation": 0.6224176842982749,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=4, lam=1]": {
#             "ridge": {
#                 "fold": 1,
#                 "hyper_params": {
#                     "degree": 4,
#                     "lam": 1
#                 },
#                 "mse_validation": 0.5283608768411331,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 1,
#                 "hyper_params": {
#                     "degree": 4,
#                     "lam": 1
#                 },
#                 "mse_validation": 0.7906338833411302,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=4, lam=10]": {
#             "ridge": {
#                 "fold": 1,
#                 "hyper_params": {
#                     "degree": 4,
#                     "lam": 10
#                 },
#                 "mse_validation": 0.527818877346802,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 1,
#                 "hyper_params": {
#                     "degree": 4,
#                     "lam": 10
#                 },
#                 "mse_validation": 0.7906338833411302,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=4, lam=100]": {
#             "ridge": {
#                 "fold": 1,
#                 "hyper_params": {
#                     "degree": 4,
#                     "lam": 100
#                 },
#                 "mse_validation": 0.5352806143692452,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 1,
#                 "hyper_params": {
#                     "degree": 4,
#                     "lam": 100
#                 },
#                 "mse_validation": 0.7906338833411302,
#                 "mse_test": null
#             }
#         }
#     },
#     {
#         "HyperParameter[degree=1, lam=0.0001]": {
#             "ridge": {
#                 "fold": 2,
#                 "hyper_params": {
#                     "degree": 1,
#                     "lam": 0.0001
#                 },
#                 "mse_validation": 0.5290507090092169,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 2,
#                 "hyper_params": {
#                     "degree": 1,
#                     "lam": 0.0001
#                 },
#                 "mse_validation": 0.5266160477446193,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=1, lam=0.001]": {
#             "ridge": {
#                 "fold": 2,
#                 "hyper_params": {
#                     "degree": 1,
#                     "lam": 0.001
#                 },
#                 "mse_validation": 0.5290498523406076,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 2,
#                 "hyper_params": {
#                     "degree": 1,
#                     "lam": 0.001
#                 },
#                 "mse_validation": 0.5264677214248558,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=1, lam=0.01]": {
#             "ridge": {
#                 "fold": 2,
#                 "hyper_params": {
#                     "degree": 1,
#                     "lam": 0.01
#                 },
#                 "mse_validation": 0.5290413166276253,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 2,
#                 "hyper_params": {
#                     "degree": 1,
#                     "lam": 0.01
#                 },
#                 "mse_validation": 0.5460919532234378,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=1, lam=0.1]": {
#             "ridge": {
#                 "fold": 2,
#                 "hyper_params": {
#                     "degree": 1,
#                     "lam": 0.1
#                 },
#                 "mse_validation": 0.5289589573159403,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 2,
#                 "hyper_params": {
#                     "degree": 1,
#                     "lam": 0.1
#                 },
#                 "mse_validation": 0.6224176842982749,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=1, lam=1]": {
#             "ridge": {
#                 "fold": 2,
#                 "hyper_params": {
#                     "degree": 1,
#                     "lam": 1
#                 },
#                 "mse_validation": 0.5283608768411331,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 2,
#                 "hyper_params": {
#                     "degree": 1,
#                     "lam": 1
#                 },
#                 "mse_validation": 0.7906338833411302,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=1, lam=10]": {
#             "ridge": {
#                 "fold": 2,
#                 "hyper_params": {
#                     "degree": 1,
#                     "lam": 10
#                 },
#                 "mse_validation": 0.527818877346802,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 2,
#                 "hyper_params": {
#                     "degree": 1,
#                     "lam": 10
#                 },
#                 "mse_validation": 0.7906338833411302,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=1, lam=100]": {
#             "ridge": {
#                 "fold": 2,
#                 "hyper_params": {
#                     "degree": 1,
#                     "lam": 100
#                 },
#                 "mse_validation": 0.5352806143692452,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 2,
#                 "hyper_params": {
#                     "degree": 1,
#                     "lam": 100
#                 },
#                 "mse_validation": 0.7906338833411302,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=2, lam=0.0001]": {
#             "ridge": {
#                 "fold": 2,
#                 "hyper_params": {
#                     "degree": 2,
#                     "lam": 0.0001
#                 },
#                 "mse_validation": 0.5290507090092169,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 2,
#                 "hyper_params": {
#                     "degree": 2,
#                     "lam": 0.0001
#                 },
#                 "mse_validation": 0.5266160477446193,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=2, lam=0.001]": {
#             "ridge": {
#                 "fold": 2,
#                 "hyper_params": {
#                     "degree": 2,
#                     "lam": 0.001
#                 },
#                 "mse_validation": 0.5290498523406076,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 2,
#                 "hyper_params": {
#                     "degree": 2,
#                     "lam": 0.001
#                 },
#                 "mse_validation": 0.5264677214248558,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=2, lam=0.01]": {
#             "ridge": {
#                 "fold": 2,
#                 "hyper_params": {
#                     "degree": 2,
#                     "lam": 0.01
#                 },
#                 "mse_validation": 0.5290413166276253,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 2,
#                 "hyper_params": {
#                     "degree": 2,
#                     "lam": 0.01
#                 },
#                 "mse_validation": 0.5460919532234378,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=2, lam=0.1]": {
#             "ridge": {
#                 "fold": 2,
#                 "hyper_params": {
#                     "degree": 2,
#                     "lam": 0.1
#                 },
#                 "mse_validation": 0.5289589573159403,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 2,
#                 "hyper_params": {
#                     "degree": 2,
#                     "lam": 0.1
#                 },
#                 "mse_validation": 0.6224176842982749,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=2, lam=1]": {
#             "ridge": {
#                 "fold": 2,
#                 "hyper_params": {
#                     "degree": 2,
#                     "lam": 1
#                 },
#                 "mse_validation": 0.5283608768411331,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 2,
#                 "hyper_params": {
#                     "degree": 2,
#                     "lam": 1
#                 },
#                 "mse_validation": 0.7906338833411302,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=2, lam=10]": {
#             "ridge": {
#                 "fold": 2,
#                 "hyper_params": {
#                     "degree": 2,
#                     "lam": 10
#                 },
#                 "mse_validation": 0.527818877346802,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 2,
#                 "hyper_params": {
#                     "degree": 2,
#                     "lam": 10
#                 },
#                 "mse_validation": 0.7906338833411302,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=2, lam=100]": {
#             "ridge": {
#                 "fold": 2,
#                 "hyper_params": {
#                     "degree": 2,
#                     "lam": 100
#                 },
#                 "mse_validation": 0.5352806143692452,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 2,
#                 "hyper_params": {
#                     "degree": 2,
#                     "lam": 100
#                 },
#                 "mse_validation": 0.7906338833411302,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=3, lam=0.0001]": {
#             "ridge": {
#                 "fold": 2,
#                 "hyper_params": {
#                     "degree": 3,
#                     "lam": 0.0001
#                 },
#                 "mse_validation": 0.5290507090092169,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 2,
#                 "hyper_params": {
#                     "degree": 3,
#                     "lam": 0.0001
#                 },
#                 "mse_validation": 0.5266160477446193,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=3, lam=0.001]": {
#             "ridge": {
#                 "fold": 2,
#                 "hyper_params": {
#                     "degree": 3,
#                     "lam": 0.001
#                 },
#                 "mse_validation": 0.5290498523406076,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 2,
#                 "hyper_params": {
#                     "degree": 3,
#                     "lam": 0.001
#                 },
#                 "mse_validation": 0.5264677214248558,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=3, lam=0.01]": {
#             "ridge": {
#                 "fold": 2,
#                 "hyper_params": {
#                     "degree": 3,
#                     "lam": 0.01
#                 },
#                 "mse_validation": 0.5290413166276253,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 2,
#                 "hyper_params": {
#                     "degree": 3,
#                     "lam": 0.01
#                 },
#                 "mse_validation": 0.5460919532234378,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=3, lam=0.1]": {
#             "ridge": {
#                 "fold": 2,
#                 "hyper_params": {
#                     "degree": 3,
#                     "lam": 0.1
#                 },
#                 "mse_validation": 0.5289589573159403,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 2,
#                 "hyper_params": {
#                     "degree": 3,
#                     "lam": 0.1
#                 },
#                 "mse_validation": 0.6224176842982749,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=3, lam=1]": {
#             "ridge": {
#                 "fold": 2,
#                 "hyper_params": {
#                     "degree": 3,
#                     "lam": 1
#                 },
#                 "mse_validation": 0.5283608768411331,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 2,
#                 "hyper_params": {
#                     "degree": 3,
#                     "lam": 1
#                 },
#                 "mse_validation": 0.7906338833411302,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=3, lam=10]": {
#             "ridge": {
#                 "fold": 2,
#                 "hyper_params": {
#                     "degree": 3,
#                     "lam": 10
#                 },
#                 "mse_validation": 0.527818877346802,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 2,
#                 "hyper_params": {
#                     "degree": 3,
#                     "lam": 10
#                 },
#                 "mse_validation": 0.7906338833411302,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=3, lam=100]": {
#             "ridge": {
#                 "fold": 2,
#                 "hyper_params": {
#                     "degree": 3,
#                     "lam": 100
#                 },
#                 "mse_validation": 0.5352806143692452,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 2,
#                 "hyper_params": {
#                     "degree": 3,
#                     "lam": 100
#                 },
#                 "mse_validation": 0.7906338833411302,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=4, lam=0.0001]": {
#             "ridge": {
#                 "fold": 2,
#                 "hyper_params": {
#                     "degree": 4,
#                     "lam": 0.0001
#                 },
#                 "mse_validation": 0.5290507090092169,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 2,
#                 "hyper_params": {
#                     "degree": 4,
#                     "lam": 0.0001
#                 },
#                 "mse_validation": 0.5266160477446193,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=4, lam=0.001]": {
#             "ridge": {
#                 "fold": 2,
#                 "hyper_params": {
#                     "degree": 4,
#                     "lam": 0.001
#                 },
#                 "mse_validation": 0.5290498523406076,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 2,
#                 "hyper_params": {
#                     "degree": 4,
#                     "lam": 0.001
#                 },
#                 "mse_validation": 0.5264677214248558,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=4, lam=0.01]": {
#             "ridge": {
#                 "fold": 2,
#                 "hyper_params": {
#                     "degree": 4,
#                     "lam": 0.01
#                 },
#                 "mse_validation": 0.5290413166276253,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 2,
#                 "hyper_params": {
#                     "degree": 4,
#                     "lam": 0.01
#                 },
#                 "mse_validation": 0.5460919532234378,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=4, lam=0.1]": {
#             "ridge": {
#                 "fold": 2,
#                 "hyper_params": {
#                     "degree": 4,
#                     "lam": 0.1
#                 },
#                 "mse_validation": 0.5289589573159403,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 2,
#                 "hyper_params": {
#                     "degree": 4,
#                     "lam": 0.1
#                 },
#                 "mse_validation": 0.6224176842982749,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=4, lam=1]": {
#             "ridge": {
#                 "fold": 2,
#                 "hyper_params": {
#                     "degree": 4,
#                     "lam": 1
#                 },
#                 "mse_validation": 0.5283608768411331,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 2,
#                 "hyper_params": {
#                     "degree": 4,
#                     "lam": 1
#                 },
#                 "mse_validation": 0.7906338833411302,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=4, lam=10]": {
#             "ridge": {
#                 "fold": 2,
#                 "hyper_params": {
#                     "degree": 4,
#                     "lam": 10
#                 },
#                 "mse_validation": 0.527818877346802,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 2,
#                 "hyper_params": {
#                     "degree": 4,
#                     "lam": 10
#                 },
#                 "mse_validation": 0.7906338833411302,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=4, lam=100]": {
#             "ridge": {
#                 "fold": 2,
#                 "hyper_params": {
#                     "degree": 4,
#                     "lam": 100
#                 },
#                 "mse_validation": 0.5352806143692452,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 2,
#                 "hyper_params": {
#                     "degree": 4,
#                     "lam": 100
#                 },
#                 "mse_validation": 0.7906338833411302,
#                 "mse_test": null
#             }
#         }
#     },
#     {
#         "HyperParameter[degree=1, lam=0.0001]": {
#             "ridge": {
#                 "fold": 3,
#                 "hyper_params": {
#                     "degree": 1,
#                     "lam": 0.0001
#                 },
#                 "mse_validation": 0.5290507090092169,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 3,
#                 "hyper_params": {
#                     "degree": 1,
#                     "lam": 0.0001
#                 },
#                 "mse_validation": 0.5266160477446193,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=1, lam=0.001]": {
#             "ridge": {
#                 "fold": 3,
#                 "hyper_params": {
#                     "degree": 1,
#                     "lam": 0.001
#                 },
#                 "mse_validation": 0.5290498523406076,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 3,
#                 "hyper_params": {
#                     "degree": 1,
#                     "lam": 0.001
#                 },
#                 "mse_validation": 0.5264677214248558,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=1, lam=0.01]": {
#             "ridge": {
#                 "fold": 3,
#                 "hyper_params": {
#                     "degree": 1,
#                     "lam": 0.01
#                 },
#                 "mse_validation": 0.5290413166276253,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 3,
#                 "hyper_params": {
#                     "degree": 1,
#                     "lam": 0.01
#                 },
#                 "mse_validation": 0.5460919532234378,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=1, lam=0.1]": {
#             "ridge": {
#                 "fold": 3,
#                 "hyper_params": {
#                     "degree": 1,
#                     "lam": 0.1
#                 },
#                 "mse_validation": 0.5289589573159403,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 3,
#                 "hyper_params": {
#                     "degree": 1,
#                     "lam": 0.1
#                 },
#                 "mse_validation": 0.6224176842982749,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=1, lam=1]": {
#             "ridge": {
#                 "fold": 3,
#                 "hyper_params": {
#                     "degree": 1,
#                     "lam": 1
#                 },
#                 "mse_validation": 0.5283608768411331,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 3,
#                 "hyper_params": {
#                     "degree": 1,
#                     "lam": 1
#                 },
#                 "mse_validation": 0.7906338833411302,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=1, lam=10]": {
#             "ridge": {
#                 "fold": 3,
#                 "hyper_params": {
#                     "degree": 1,
#                     "lam": 10
#                 },
#                 "mse_validation": 0.527818877346802,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 3,
#                 "hyper_params": {
#                     "degree": 1,
#                     "lam": 10
#                 },
#                 "mse_validation": 0.7906338833411302,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=1, lam=100]": {
#             "ridge": {
#                 "fold": 3,
#                 "hyper_params": {
#                     "degree": 1,
#                     "lam": 100
#                 },
#                 "mse_validation": 0.5352806143692452,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 3,
#                 "hyper_params": {
#                     "degree": 1,
#                     "lam": 100
#                 },
#                 "mse_validation": 0.7906338833411302,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=2, lam=0.0001]": {
#             "ridge": {
#                 "fold": 3,
#                 "hyper_params": {
#                     "degree": 2,
#                     "lam": 0.0001
#                 },
#                 "mse_validation": 0.5290507090092169,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 3,
#                 "hyper_params": {
#                     "degree": 2,
#                     "lam": 0.0001
#                 },
#                 "mse_validation": 0.5266160477446193,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=2, lam=0.001]": {
#             "ridge": {
#                 "fold": 3,
#                 "hyper_params": {
#                     "degree": 2,
#                     "lam": 0.001
#                 },
#                 "mse_validation": 0.5290498523406076,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 3,
#                 "hyper_params": {
#                     "degree": 2,
#                     "lam": 0.001
#                 },
#                 "mse_validation": 0.5264677214248558,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=2, lam=0.01]": {
#             "ridge": {
#                 "fold": 3,
#                 "hyper_params": {
#                     "degree": 2,
#                     "lam": 0.01
#                 },
#                 "mse_validation": 0.5290413166276253,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 3,
#                 "hyper_params": {
#                     "degree": 2,
#                     "lam": 0.01
#                 },
#                 "mse_validation": 0.5460919532234378,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=2, lam=0.1]": {
#             "ridge": {
#                 "fold": 3,
#                 "hyper_params": {
#                     "degree": 2,
#                     "lam": 0.1
#                 },
#                 "mse_validation": 0.5289589573159403,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 3,
#                 "hyper_params": {
#                     "degree": 2,
#                     "lam": 0.1
#                 },
#                 "mse_validation": 0.6224176842982749,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=2, lam=1]": {
#             "ridge": {
#                 "fold": 3,
#                 "hyper_params": {
#                     "degree": 2,
#                     "lam": 1
#                 },
#                 "mse_validation": 0.5283608768411331,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 3,
#                 "hyper_params": {
#                     "degree": 2,
#                     "lam": 1
#                 },
#                 "mse_validation": 0.7906338833411302,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=2, lam=10]": {
#             "ridge": {
#                 "fold": 3,
#                 "hyper_params": {
#                     "degree": 2,
#                     "lam": 10
#                 },
#                 "mse_validation": 0.527818877346802,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 3,
#                 "hyper_params": {
#                     "degree": 2,
#                     "lam": 10
#                 },
#                 "mse_validation": 0.7906338833411302,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=2, lam=100]": {
#             "ridge": {
#                 "fold": 3,
#                 "hyper_params": {
#                     "degree": 2,
#                     "lam": 100
#                 },
#                 "mse_validation": 0.5352806143692452,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 3,
#                 "hyper_params": {
#                     "degree": 2,
#                     "lam": 100
#                 },
#                 "mse_validation": 0.7906338833411302,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=3, lam=0.0001]": {
#             "ridge": {
#                 "fold": 3,
#                 "hyper_params": {
#                     "degree": 3,
#                     "lam": 0.0001
#                 },
#                 "mse_validation": 0.5290507090092169,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 3,
#                 "hyper_params": {
#                     "degree": 3,
#                     "lam": 0.0001
#                 },
#                 "mse_validation": 0.5266160477446193,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=3, lam=0.001]": {
#             "ridge": {
#                 "fold": 3,
#                 "hyper_params": {
#                     "degree": 3,
#                     "lam": 0.001
#                 },
#                 "mse_validation": 0.5290498523406076,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 3,
#                 "hyper_params": {
#                     "degree": 3,
#                     "lam": 0.001
#                 },
#                 "mse_validation": 0.5264677214248558,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=3, lam=0.01]": {
#             "ridge": {
#                 "fold": 3,
#                 "hyper_params": {
#                     "degree": 3,
#                     "lam": 0.01
#                 },
#                 "mse_validation": 0.5290413166276253,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 3,
#                 "hyper_params": {
#                     "degree": 3,
#                     "lam": 0.01
#                 },
#                 "mse_validation": 0.5460919532234378,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=3, lam=0.1]": {
#             "ridge": {
#                 "fold": 3,
#                 "hyper_params": {
#                     "degree": 3,
#                     "lam": 0.1
#                 },
#                 "mse_validation": 0.5289589573159403,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 3,
#                 "hyper_params": {
#                     "degree": 3,
#                     "lam": 0.1
#                 },
#                 "mse_validation": 0.6224176842982749,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=3, lam=1]": {
#             "ridge": {
#                 "fold": 3,
#                 "hyper_params": {
#                     "degree": 3,
#                     "lam": 1
#                 },
#                 "mse_validation": 0.5283608768411331,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 3,
#                 "hyper_params": {
#                     "degree": 3,
#                     "lam": 1
#                 },
#                 "mse_validation": 0.7906338833411302,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=3, lam=10]": {
#             "ridge": {
#                 "fold": 3,
#                 "hyper_params": {
#                     "degree": 3,
#                     "lam": 10
#                 },
#                 "mse_validation": 0.527818877346802,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 3,
#                 "hyper_params": {
#                     "degree": 3,
#                     "lam": 10
#                 },
#                 "mse_validation": 0.7906338833411302,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=3, lam=100]": {
#             "ridge": {
#                 "fold": 3,
# ...
#                 "hyper_params": {
#                     "degree": 1,
#                     "lam": 0.001
#                 },
#                 "mse_validation": 0.5290498523406076,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 5,
#                 "hyper_params": {
#                     "degree": 1,
#                     "lam": 0.001
#                 },
#                 "mse_validation": 0.5264677214248558,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=1, lam=0.01]": {
#             "ridge": {
#                 "fold": 5,
#                 "hyper_params": {
#                     "degree": 1,
#                     "lam": 0.01
#                 },
#                 "mse_validation": 0.5290413166276253,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 5,
#                 "hyper_params": {
#                     "degree": 1,
#                     "lam": 0.01
#                 },
#                 "mse_validation": 0.5460919532234378,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=1, lam=0.1]": {
#             "ridge": {
#                 "fold": 5,
#                 "hyper_params": {
#                     "degree": 1,
#                     "lam": 0.1
#                 },
#                 "mse_validation": 0.5289589573159403,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 5,
#                 "hyper_params": {
#                     "degree": 1,
#                     "lam": 0.1
#                 },
#                 "mse_validation": 0.6224176842982749,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=1, lam=1]": {
#             "ridge": {
#                 "fold": 5,
#                 "hyper_params": {
#                     "degree": 1,
#                     "lam": 1
#                 },
#                 "mse_validation": 0.5283608768411331,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 5,
#                 "hyper_params": {
#                     "degree": 1,
#                     "lam": 1
#                 },
#                 "mse_validation": 0.7906338833411302,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=1, lam=10]": {
#             "ridge": {
#                 "fold": 5,
#                 "hyper_params": {
#                     "degree": 1,
#                     "lam": 10
#                 },
#                 "mse_validation": 0.527818877346802,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 5,
#                 "hyper_params": {
#                     "degree": 1,
#                     "lam": 10
#                 },
#                 "mse_validation": 0.7906338833411302,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=1, lam=100]": {
#             "ridge": {
#                 "fold": 5,
#                 "hyper_params": {
#                     "degree": 1,
#                     "lam": 100
#                 },
#                 "mse_validation": 0.5352806143692452,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 5,
#                 "hyper_params": {
#                     "degree": 1,
#                     "lam": 100
#                 },
#                 "mse_validation": 0.7906338833411302,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=2, lam=0.0001]": {
#             "ridge": {
#                 "fold": 5,
#                 "hyper_params": {
#                     "degree": 2,
#                     "lam": 0.0001
#                 },
#                 "mse_validation": 0.5290507090092169,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 5,
#                 "hyper_params": {
#                     "degree": 2,
#                     "lam": 0.0001
#                 },
#                 "mse_validation": 0.5266160477446193,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=2, lam=0.001]": {
#             "ridge": {
#                 "fold": 5,
#                 "hyper_params": {
#                     "degree": 2,
#                     "lam": 0.001
#                 },
#                 "mse_validation": 0.5290498523406076,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 5,
#                 "hyper_params": {
#                     "degree": 2,
#                     "lam": 0.001
#                 },
#                 "mse_validation": 0.5264677214248558,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=2, lam=0.01]": {
#             "ridge": {
#                 "fold": 5,
#                 "hyper_params": {
#                     "degree": 2,
#                     "lam": 0.01
#                 },
#                 "mse_validation": 0.5290413166276253,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 5,
#                 "hyper_params": {
#                     "degree": 2,
#                     "lam": 0.01
#                 },
#                 "mse_validation": 0.5460919532234378,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=2, lam=0.1]": {
#             "ridge": {
#                 "fold": 5,
#                 "hyper_params": {
#                     "degree": 2,
#                     "lam": 0.1
#                 },
#                 "mse_validation": 0.5289589573159403,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 5,
#                 "hyper_params": {
#                     "degree": 2,
#                     "lam": 0.1
#                 },
#                 "mse_validation": 0.6224176842982749,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=2, lam=1]": {
#             "ridge": {
#                 "fold": 5,
#                 "hyper_params": {
#                     "degree": 2,
#                     "lam": 1
#                 },
#                 "mse_validation": 0.5283608768411331,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 5,
#                 "hyper_params": {
#                     "degree": 2,
#                     "lam": 1
#                 },
#                 "mse_validation": 0.7906338833411302,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=2, lam=10]": {
#             "ridge": {
#                 "fold": 5,
#                 "hyper_params": {
#                     "degree": 2,
#                     "lam": 10
#                 },
#                 "mse_validation": 0.527818877346802,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 5,
#                 "hyper_params": {
#                     "degree": 2,
#                     "lam": 10
#                 },
#                 "mse_validation": 0.7906338833411302,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=2, lam=100]": {
#             "ridge": {
#                 "fold": 5,
#                 "hyper_params": {
#                     "degree": 2,
#                     "lam": 100
#                 },
#                 "mse_validation": 0.5352806143692452,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 5,
#                 "hyper_params": {
#                     "degree": 2,
#                     "lam": 100
#                 },
#                 "mse_validation": 0.7906338833411302,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=3, lam=0.0001]": {
#             "ridge": {
#                 "fold": 5,
#                 "hyper_params": {
#                     "degree": 3,
#                     "lam": 0.0001
#                 },
#                 "mse_validation": 0.5290507090092169,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 5,
#                 "hyper_params": {
#                     "degree": 3,
#                     "lam": 0.0001
#                 },
#                 "mse_validation": 0.5266160477446193,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=3, lam=0.001]": {
#             "ridge": {
#                 "fold": 5,
#                 "hyper_params": {
#                     "degree": 3,
#                     "lam": 0.001
#                 },
#                 "mse_validation": 0.5290498523406076,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 5,
#                 "hyper_params": {
#                     "degree": 3,
#                     "lam": 0.001
#                 },
#                 "mse_validation": 0.5264677214248558,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=3, lam=0.01]": {
#             "ridge": {
#                 "fold": 5,
#                 "hyper_params": {
#                     "degree": 3,
#                     "lam": 0.01
#                 },
#                 "mse_validation": 0.5290413166276253,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 5,
#                 "hyper_params": {
#                     "degree": 3,
#                     "lam": 0.01
#                 },
#                 "mse_validation": 0.5460919532234378,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=3, lam=0.1]": {
#             "ridge": {
#                 "fold": 5,
#                 "hyper_params": {
#                     "degree": 3,
#                     "lam": 0.1
#                 },
#                 "mse_validation": 0.5289589573159403,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 5,
#                 "hyper_params": {
#                     "degree": 3,
#                     "lam": 0.1
#                 },
#                 "mse_validation": 0.6224176842982749,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=3, lam=1]": {
#             "ridge": {
#                 "fold": 5,
#                 "hyper_params": {
#                     "degree": 3,
#                     "lam": 1
#                 },
#                 "mse_validation": 0.5283608768411331,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 5,
#                 "hyper_params": {
#                     "degree": 3,
#                     "lam": 1
#                 },
#                 "mse_validation": 0.7906338833411302,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=3, lam=10]": {
#             "ridge": {
#                 "fold": 5,
#                 "hyper_params": {
#                     "degree": 3,
#                     "lam": 10
#                 },
#                 "mse_validation": 0.527818877346802,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 5,
#                 "hyper_params": {
#                     "degree": 3,
#                     "lam": 10
#                 },
#                 "mse_validation": 0.7906338833411302,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=3, lam=100]": {
#             "ridge": {
#                 "fold": 5,
#                 "hyper_params": {
#                     "degree": 3,
#                     "lam": 100
#                 },
#                 "mse_validation": 0.5352806143692452,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 5,
#                 "hyper_params": {
#                     "degree": 3,
#                     "lam": 100
#                 },
#                 "mse_validation": 0.7906338833411302,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=4, lam=0.0001]": {
#             "ridge": {
#                 "fold": 5,
#                 "hyper_params": {
#                     "degree": 4,
#                     "lam": 0.0001
#                 },
#                 "mse_validation": 0.5290507090092169,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 5,
#                 "hyper_params": {
#                     "degree": 4,
#                     "lam": 0.0001
#                 },
#                 "mse_validation": 0.5266160477446193,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=4, lam=0.001]": {
#             "ridge": {
#                 "fold": 5,
#                 "hyper_params": {
#                     "degree": 4,
#                     "lam": 0.001
#                 },
#                 "mse_validation": 0.5290498523406076,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 5,
#                 "hyper_params": {
#                     "degree": 4,
#                     "lam": 0.001
#                 },
#                 "mse_validation": 0.5264677214248558,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=4, lam=0.01]": {
#             "ridge": {
#                 "fold": 5,
#                 "hyper_params": {
#                     "degree": 4,
#                     "lam": 0.01
#                 },
#                 "mse_validation": 0.5290413166276253,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 5,
#                 "hyper_params": {
#                     "degree": 4,
#                     "lam": 0.01
#                 },
#                 "mse_validation": 0.5460919532234378,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=4, lam=0.1]": {
#             "ridge": {
#                 "fold": 5,
#                 "hyper_params": {
#                     "degree": 4,
#                     "lam": 0.1
#                 },
#                 "mse_validation": 0.5289589573159403,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 5,
#                 "hyper_params": {
#                     "degree": 4,
#                     "lam": 0.1
#                 },
#                 "mse_validation": 0.6224176842982749,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=4, lam=1]": {
#             "ridge": {
#                 "fold": 5,
#                 "hyper_params": {
#                     "degree": 4,
#                     "lam": 1
#                 },
#                 "mse_validation": 0.5283608768411331,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 5,
#                 "hyper_params": {
#                     "degree": 4,
#                     "lam": 1
#                 },
#                 "mse_validation": 0.7906338833411302,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=4, lam=10]": {
#             "ridge": {
#                 "fold": 5,
#                 "hyper_params": {
#                     "degree": 4,
#                     "lam": 10
#                 },
#                 "mse_validation": 0.527818877346802,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 5,
#                 "hyper_params": {
#                     "degree": 4,
#                     "lam": 10
#                 },
#                 "mse_validation": 0.7906338833411302,
#                 "mse_test": null
#             }
#         },
#         "HyperParameter[degree=4, lam=100]": {
#             "ridge": {
#                 "fold": 5,
#                 "hyper_params": {
#                     "degree": 4,
#                     "lam": 100
#                 },
#                 "mse_validation": 0.5352806143692452,
#                 "mse_test": null
#             },
#             "lasso": {
#                 "fold": 5,
#                 "hyper_params": {
#                     "degree": 4,
#                     "lam": 100
#                 },
#                 "mse_validation": 0.7906338833411302,
#                 "mse_test": null
#             }
#         }
#     }
# ]

# %%
hyperparameter_means : Dict[str, Dict[str, float]] = {}

best_lasso_mse = 10000
best_lasso_params : HyperParameter = None
best_ridge_mse = 10000
best_ridge_params : HyperParameter = None

for param_string in fold_results[1]:
    results_lasso = []
    results_ridge = []
    for fold in range(1, 5):
        fold_result = fold_results[fold][param_string]
        results_lasso.append(fold_result.lasso.mse_validation)
        results_ridge.append(fold_result.ridge.mse_validation)
    hyperparameter_means[param_string]={}

    lasso_mean = sum(results_lasso) / results_lasso.__len__()
    hyperparameter_means[param_string]['lasso'] = lasso_mean
    if lasso_mean < best_lasso_mse:
        best_lasso_mse = lasso_mean
        best_lasso_params = fold_results[1][param_string].lasso.hyper_params

    ridge_mean = sum(results_ridge) / results_ridge.__len__()
    hyperparameter_means[param_string]['ridge'] = ridge_mean
    if ridge_mean < best_ridge_mse:
        best_ridge_mse = ridge_mean
        best_ridge_params = fold_results[1][param_string].ridge.hyper_params

def evaluate_model(model, degree : int) -> float:
    expanded = expand_basis(X_train, degree)
    test_expanded = expand_basis(X_test, degree)
    model.fit(expanded, y_train)
    predicted = model.predict(test_expanded)
    mse = mean_squared_error(y_test, predicted)
    return mse


mse_lasso = evaluate_model(Lasso(alpha=best_lasso_params.lam), best_lasso_params.degree)
mse_ridge = evaluate_model(Ridge(alpha=best_ridge_params.lam), best_ridge_params.degree)

print(f'Best Lasso Parameters: {best_lasso_params}, mean mse on cross validation: {best_lasso_mse}, mse on whole X_test: {mse_lasso}')
print(f'Best Ridge Parameters: {best_ridge_params}, mean mse on cross validation: {best_ridge_mse}, mse on whole X_test: {mse_ridge}')
# Out:
# Best Lasso Parameters: HyperParameter[degree=1, lam=0.001], mean mse on cross validation: 0.5264677214248558, mse on whole X_test: 0.5610049030906814
# Best Ridge Parameters: HyperParameter[degree=1, lam=10], mean mse on cross validation: 0.527818877346802, mse on whole X_test: 0.5608929799915933

# %%
print('mean mse of all parameters:')
print(json.dumps(hyperparameter_means, indent=4))
# Out:
# mean mse of all parameters:
# {
#     "HyperParameter[degree=1, lam=0.0001]": {
#         "lasso": 0.5266160477446193,
#         "ridge": 0.5290507090092169
#     },
#     "HyperParameter[degree=1, lam=0.001]": {
#         "lasso": 0.5264677214248558,
#         "ridge": 0.5290498523406076
#     },
#     "HyperParameter[degree=1, lam=0.01]": {
#         "lasso": 0.5460919532234378,
#         "ridge": 0.5290413166276253
#     },
#     "HyperParameter[degree=1, lam=0.1]": {
#         "lasso": 0.6224176842982749,
#         "ridge": 0.5289589573159403
#     },
#     "HyperParameter[degree=1, lam=1]": {
#         "lasso": 0.7906338833411302,
#         "ridge": 0.5283608768411331
#     },
#     "HyperParameter[degree=1, lam=10]": {
#         "lasso": 0.7906338833411302,
#         "ridge": 0.527818877346802
#     },
#     "HyperParameter[degree=1, lam=100]": {
#         "lasso": 0.7906338833411302,
#         "ridge": 0.5352806143692452
#     },
#     "HyperParameter[degree=2, lam=0.0001]": {
#         "lasso": 0.5266160477446193,
#         "ridge": 0.5290507090092169
#     },
#     "HyperParameter[degree=2, lam=0.001]": {
#         "lasso": 0.5264677214248558,
#         "ridge": 0.5290498523406076
#     },
#     "HyperParameter[degree=2, lam=0.01]": {
#         "lasso": 0.5460919532234378,
#         "ridge": 0.5290413166276253
#     },
#     "HyperParameter[degree=2, lam=0.1]": {
#         "lasso": 0.6224176842982749,
#         "ridge": 0.5289589573159403
#     },
#     "HyperParameter[degree=2, lam=1]": {
#         "lasso": 0.7906338833411302,
#         "ridge": 0.5283608768411331
#     },
#     "HyperParameter[degree=2, lam=10]": {
#         "lasso": 0.7906338833411302,
#         "ridge": 0.527818877346802
#     },
#     "HyperParameter[degree=2, lam=100]": {
#         "lasso": 0.7906338833411302,
#         "ridge": 0.5352806143692452
#     },
#     "HyperParameter[degree=3, lam=0.0001]": {
#         "lasso": 0.5266160477446193,
#         "ridge": 0.5290507090092169
#     },
#     "HyperParameter[degree=3, lam=0.001]": {
#         "lasso": 0.5264677214248558,
#         "ridge": 0.5290498523406076
#     },
#     "HyperParameter[degree=3, lam=0.01]": {
#         "lasso": 0.5460919532234378,
#         "ridge": 0.5290413166276253
#     },
#     "HyperParameter[degree=3, lam=0.1]": {
#         "lasso": 0.6224176842982749,
#         "ridge": 0.5289589573159403
#     },
#     "HyperParameter[degree=3, lam=1]": {
#         "lasso": 0.7906338833411302,
#         "ridge": 0.5283608768411331
#     },
#     "HyperParameter[degree=3, lam=10]": {
#         "lasso": 0.7906338833411302,
#         "ridge": 0.527818877346802
#     },
#     "HyperParameter[degree=3, lam=100]": {
#         "lasso": 0.7906338833411302,
#         "ridge": 0.5352806143692452
#     },
#     "HyperParameter[degree=4, lam=0.0001]": {
#         "lasso": 0.5266160477446193,
#         "ridge": 0.5290507090092169
#     },
#     "HyperParameter[degree=4, lam=0.001]": {
#         "lasso": 0.5264677214248558,
#         "ridge": 0.5290498523406076
#     },
#     "HyperParameter[degree=4, lam=0.01]": {
#         "lasso": 0.5460919532234378,
#         "ridge": 0.5290413166276253
#     },
#     "HyperParameter[degree=4, lam=0.1]": {
#         "lasso": 0.6224176842982749,
#         "ridge": 0.5289589573159403
#     },
#     "HyperParameter[degree=4, lam=1]": {
#         "lasso": 0.7906338833411302,
#         "ridge": 0.5283608768411331
#     },
#     "HyperParameter[degree=4, lam=10]": {
#         "lasso": 0.7906338833411302,
#         "ridge": 0.527818877346802
#     },
#     "HyperParameter[degree=4, lam=100]": {
#         "lasso": 0.7906338833411302,
#         "ridge": 0.5352806143692452
#     }
# }
